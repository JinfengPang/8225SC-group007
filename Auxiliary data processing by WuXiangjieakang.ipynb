# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define the path to your train data file
data_path = "./Datasets/train.csv"

# Load the data into a Pandas DataFrame
df = pd.read_csv(data_path)

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#   rent_approval_date             town block            street_name  flat_type  \
# 0            2021-09      jurong east   257  Jurong East Street 24     3 room
# 1            2022-05            bedok   119       bedok north road     4-room
# 2            2022-10        toa payoh   157     lorong 1 toa payoh     3-room
# 3            2021-08        pasir ris   250    Pasir Ris Street 21  executive
# 4            2022-11  kallang/whampoa    34           Whampoa West     3-room
#
#        flat_model  floor_area_sqm furnished  lease_commence_date  latitude  \
# 0  new generation            67.0       yes                 1983  1.344518
# 1  new generation            92.0       yes                 1978  1.330186
# 2        improved            67.0       yes                 1971  1.332242
# 3       apartment           149.0       yes                 1993  1.370239
# 4        improved            68.0       yes                 1972  1.320502
#
#     longitude  elevation            subzone planning_area          region  \
# 0  103.738630        0.0         yuhua east   jurong east     west region
# 1  103.938717        0.0        bedok north         bedok     east region
# 2  103.845643        0.0  toa payoh central     toa payoh  central region
# 3  103.962894        0.0    pasir ris drive     pasir ris     east region
# 4  103.863341        0.0          bendemeer       kallang  central region
#
#    monthly_rent
# 0          1600
# 1          2250
# 2          1900
# 3          2850
# 4          2100

# %%
# Get basic summary statistics for numerical columns
df.describe()
# Out:
#        floor_area_sqm  lease_commence_date      latitude     longitude  \
# count    60000.000000         60000.000000  60000.000000  60000.000000
# mean        94.480458          1990.876367      1.359443    103.840110
# std         24.082642            12.141435      0.042505      0.071627
# min         34.000000          1966.000000      1.270380    103.685228
# 25%         73.000000          1981.000000      1.330939    103.778803
# 50%         93.000000          1988.000000      1.354024    103.845301
# 75%        110.000000          2000.000000      1.386968    103.897418
# max        215.000000          2019.000000      1.457071    103.964915
#
#        elevation  monthly_rent
# count    60000.0  60000.000000
# mean         0.0   2590.328333
# std          0.0    714.910468
# min          0.0    300.000000
# 25%          0.0   2100.000000
# 50%          0.0   2400.000000
# 75%          0.0   3000.000000
# max          0.0   6950.000000

# %%
# Get information about the data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rent_approval_date   60000 non-null  object
#  1   town                 60000 non-null  object
#  2   block                60000 non-null  object
#  3   street_name          60000 non-null  object
#  4   flat_type            60000 non-null  object
#  5   flat_model           60000 non-null  object
#  6   floor_area_sqm       60000 non-null  float64
#  7   furnished            60000 non-null  object
#  8   lease_commence_date  60000 non-null  int64
#  9   latitude             60000 non-null  float64
#  10  longitude            60000 non-null  float64
#  11  elevation            60000 non-null  float64
#  12  subzone              60000 non-null  object
#  13  planning_area        60000 non-null  object
#  14  region               60000 non-null  object
#  15  monthly_rent         60000 non-null  int64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 7.3+ MB

# %%
# Check unique values in categorical columns
print(f' Unique value in rent_approval_date: {df["rent_approval_date"].unique()}')
print(f' Unique value in town: {df["town"].unique()}')
print(f' Unique value in block: {df["block"].unique()}')
print(f' Unique value in street_name: {df["street_name"].unique()}')
print(f' Unique value in flat_type: {df["flat_type"].unique()}')
print(f' Unique value in flat_model: {df["flat_model"].unique()}')
# Out:
#  Unique value in rent_approval_date: ['2021-09' '2022-05' '2022-10' '2021-08' '2022-11' '2023-04' '2021-01'
#  '2022-06' '2021-10' '2021-04' '2021-03' '2022-02' '2021-07' '2022-12'
#  '2023-01' '2022-01' '2023-07' '2021-06' '2023-05' '2023-03' '2021-05'
#  '2021-02' '2022-07' '2023-06' '2022-03' '2023-02' '2021-12' '2022-04'
#  '2021-11' '2022-08' '2022-09']
#  Unique value in town: ['jurong east' 'bedok' 'toa payoh' 'pasir ris' 'kallang/whampoa'
#  'bukit panjang' 'sengkang' 'ang mo kio' 'bishan' 'punggol'
#  'choa chu kang' 'clementi' 'bukit batok' 'sembawang' 'jurong west'
#  'woodlands' 'queenstown' 'yishun' 'bukit timah' 'marine parade'
#  'bukit merah' 'geylang' 'hougang' 'tampines' 'serangoon' 'central']
#  Unique value in block: ['257' '119' '157' ... '509c' '218a' '880a']
#  Unique value in street_name: ['Jurong East Street 24' 'bedok north road' 'lorong 1 toa payoh' ...
#  'seng poh road' 'Jurong West Street 51' 'Zion Road']
#  Unique value in flat_type: ['3 room' '4-room' '3-room' 'executive' '5 room' '4 room' '5-room'
#  '2-room' '2 room']
#  Unique value in flat_model: ['new generation' 'improved' 'apartment' 'premium apartment' 'simplified'
#  'model a' 'standard' 'dbss' 'model a2' 'maisonette' 'model a-maisonette'
#  'type s1' 'adjoined flat' 'type s2' 'premium apartment loft' '2-room'
#  'premium maisonette' 'terrace' '3gen']

# %% [markdown]
# # Process the first column(rent_approval_date)

# %%
# Check the data type of the 'rent_approval_date' column
df['rent_approval_date'].dtype
# Out:
# dtype('O')

# %%
# Convert 'rent_approval_date' to a datetime data type
df['rent_approval_date'] = pd.to_datetime(df['rent_approval_date'])
df['rent_approval_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Extract year, month, and day
approval_year = df['rent_approval_date'].dt.year
approval_month= df['rent_approval_date'].dt.month
approval_day = df['rent_approval_date'].dt.day

# %%
# Example: Line plot of average monthly rent over years
plt.figure(figsize=(12, 6))
sns.lineplot(x=approval_year, y='monthly_rent', data=df)
plt.title("Average Monthly Rent Over the Years")
plt.xlabel("Year")
plt.ylabel("Average Monthly Rent (SGD)")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Example: Box plot of monthly rent by month
plt.figure(figsize=(12, 6))
sns.boxplot(x=approval_month, y='monthly_rent', data=df)
plt.title("Monthly Rent Distribution by Month")
plt.xlabel("Month")
plt.ylabel("Monthly Rent (SGD)")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd

# Define a reference date (e.g., the earliest date in the dataset)
reference_date = df['rent_approval_date'].min()

# Calculate the number of months from the reference date
df['rent_approval_date'] = (df['rent_approval_date'] - reference_date) // pd.Timedelta(days=30)

# Display the transformed DataFrame
print(df[['rent_approval_date']])
# Out:
#        rent_approval_date
# 0                       8
# 1                      16
# 2                      21
# 3                       7
# 4                      22
# ...                   ...
# 59995                   8
# 59996                  27
# 59997                  17
# 59998                  24
# 59999                  25
#
# [60000 rows x 1 columns]

# %% [markdown]
# # Process the second column(town)

# %%
# Display the frequency distribution of towns
town_counts = df['town'].value_counts()
print(town_counts)
# Out:
# town
# jurong west        4413
# tampines           4183
# sengkang           4003
# bedok              3644
# ang mo kio         3494
# yishun             3378
# bukit merah        3160
# woodlands          3031
# hougang            2859
# punggol            2700
# toa payoh          2407
# clementi           2272
# bukit batok        2236
# choa chu kang      2117
# queenstown         2033
# kallang/whampoa    1860
# geylang            1716
# pasir ris          1712
# jurong east        1710
# bukit panjang      1607
# sembawang          1446
# bishan             1437
# serangoon          1299
# central             615
# marine parade       612
# bukit timah          56
# Name: count, dtype: int64

# %%
# Create a box plot of monthly rent by town
plt.figure(figsize=(12, 6))
sns.boxplot(x='town', y='monthly_rent', data=df)
plt.title("Monthly Rent Distribution by Town")
plt.xlabel("Town")
plt.ylabel("Monthly Rent (SGD)")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Target Encoding
# Calculate the mean monthly rent for each town
town_mean_rent = df.groupby('town')['monthly_rent'].mean().to_dict()

# Map the mean rent values to the 'town' column
df['town'] = df['town'].map(town_mean_rent)

# %%
df.head()
# Out:
#    rent_approval_date         town block            street_name  flat_type  \
# 0                   8  2595.146199   257  Jurong East Street 24     3 room
# 1                  16  2438.227223   119       bedok north road     4-room
# 2                  21  2516.680515   157     lorong 1 toa payoh     3-room
# 3                   7  2686.857477   250    Pasir Ris Street 21  executive
# 4                  22  2665.537634    34           Whampoa West     3-room
#
#        flat_model  floor_area_sqm furnished  lease_commence_date  latitude  \
# 0  new generation            67.0       yes                 1983  1.344518
# 1  new generation            92.0       yes                 1978  1.330186
# 2        improved            67.0       yes                 1971  1.332242
# 3       apartment           149.0       yes                 1993  1.370239
# 4        improved            68.0       yes                 1972  1.320502
#
#     longitude  elevation            subzone planning_area          region  \
# 0  103.738630        0.0         yuhua east   jurong east     west region
# 1  103.938717        0.0        bedok north         bedok     east region
# 2  103.845643        0.0  toa payoh central     toa payoh  central region
# 3  103.962894        0.0    pasir ris drive     pasir ris     east region
# 4  103.863341        0.0          bendemeer       kallang  central region
#
#    monthly_rent
# 0          1600
# 1          2250
# 2          1900
# 3          2850
# 4          2100

# %% [markdown]
# # Process the third column(blk)

# %%
# Remove non-numeric characters from the 'block' column and convert to numeric
df['block'] = df['block'].str.replace(r'\D+', '', regex=True).astype(int)

# %%
df['block']
# Out:
# 0        257
# 1        119
# 2        157
# 3        250
# 4         34
#         ...
# 59995    441
# 59996     95
# 59997    862
# 59998     67
# 59999    445
# Name: block, Length: 60000, dtype: int32

# %% [markdown]
# # Process the fifth column(blk)

# %%
# Map 'executive' to '6' and fill missing values with a default value, e.g., -1
df['flat_type'] = df['flat_type'].replace('executive', '6')
# Remove non-numeric characters and handle 'executive' values
df['flat_type'] = df['flat_type'].str.extract('(\d)', expand=False)

df['flat_type']
# Out:
# 0        3
# 1        4
# 2        3
# 3        6
# 4        3
#         ..
# 59995    3
# 59996    4
# 59997    5
# 59998    5
# 59999    3
# Name: flat_type, Length: 60000, dtype: object

# %%
# Create a bar plot of flat types
plt.figure(figsize=(10, 6))
sns.countplot(x='flat_type', data=df)
plt.title("Distribution of Flat Types")
plt.xlabel("Flat Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df.head()
# Out:
#    rent_approval_date         town  block            street_name flat_type  \
# 0                   8  2595.146199    257  Jurong East Street 24         3
# 1                  16  2438.227223    119       bedok north road         4
# 2                  21  2516.680515    157     lorong 1 toa payoh         3
# 3                   7  2686.857477    250    Pasir Ris Street 21         6
# 4                  22  2665.537634     34           Whampoa West         3
#
#        flat_model  floor_area_sqm furnished  lease_commence_date  latitude  \
# 0  new generation            67.0       yes                 1983  1.344518
# 1  new generation            92.0       yes                 1978  1.330186
# 2        improved            67.0       yes                 1971  1.332242
# 3       apartment           149.0       yes                 1993  1.370239
# 4        improved            68.0       yes                 1972  1.320502
#
#     longitude  elevation            subzone planning_area          region  \
# 0  103.738630        0.0         yuhua east   jurong east     west region
# 1  103.938717        0.0        bedok north         bedok     east region
# 2  103.845643        0.0  toa payoh central     toa payoh  central region
# 3  103.962894        0.0    pasir ris drive     pasir ris     east region
# 4  103.863341        0.0          bendemeer       kallang  central region
#
#    monthly_rent
# 0          1600
# 1          2250
# 2          1900
# 3          2850
# 4          2100

# %%
# Create a box plot of monthly rent by flat type
plt.figure(figsize=(12, 6))
sns.boxplot(x='flat_type', y='monthly_rent', data=df)
plt.title("Monthly Rent Distribution by Flat Type")
plt.xlabel("Flat Type")
plt.ylabel("Monthly Rent (SGD)")
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Process the sixth column(model)

# %%
# Display the frequency distribution of flat models
flat_model_counts = df['flat_model'].value_counts()
print(flat_model_counts)
# Out:
# flat_model
# model a                   17122
# improved                  17010
# new generation            11292
# premium apartment          5109
# simplified                 2798
# standard                   2268
# apartment                  2080
# maisonette                  956
# model a2                    663
# dbss                        371
# type s1                     108
# model a-maisonette           56
# adjoined flat                49
# type s2                      46
# 2-room                       34
# premium apartment loft       25
# premium maisonette            6
# terrace                       4
# 3gen                          3
# Name: count, dtype: int64

# %%
# Create a bar plot of flat models
plt.figure(figsize=(12, 6))
sns.countplot(x='flat_model', data=df)
plt.title("Distribution of Flat Models")
plt.xlabel("Flat Model")
plt.ylabel("Count")
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean monthly rent for each flat model
flat_model_mean_rent = df.groupby('flat_model')['monthly_rent'].mean().reset_index()

# Sort the DataFrame by mean rent values in descending order
flat_model_mean_rent = flat_model_mean_rent.sort_values(by='monthly_rent', ascending=False)

# Create a bar plot of mean monthly rent by flat model
plt.figure(figsize=(12, 6))
sns.barplot(x='monthly_rent', y='flat_model', data=flat_model_mean_rent, orient='h')
plt.title("Average Monthly Rent by Flat Model")
plt.xlabel("Average Monthly Rent (SGD)")
plt.ylabel("Flat Model")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# there is a potential relationship between the 'flat_model' categories and the target variable (e.g., 'monthly_rent'). Target encoding can capture the impact of each 'flat_model' category on the target variable.

# %%
# Calculate the mean monthly rent for each 'flat_model'
flat_model_means = df.groupby('flat_model')['monthly_rent'].mean().to_dict()

# Map the mean rent values to the 'flat_model' column
df['flat_model'] = df['flat_model'].map(flat_model_means)

# Display the encoded column
print(df['flat_model'])
# Out:
# 0        2369.965462
# 1        2369.965462
# 2        2636.211052
# 3        2878.725962
# 4        2636.211052
#             ...
# 59995    2369.965462
# 59996    2612.031305
# 59997    2636.211052
# 59998    2444.223986
# 59999    2369.965462
# Name: flat_model, Length: 60000, dtype: float64

# %%
df.head()
# Out:
#    rent_approval_date         town  block            street_name flat_type  \
# 0                   8  2595.146199    257  Jurong East Street 24         3
# 1                  16  2438.227223    119       bedok north road         4
# 2                  21  2516.680515    157     lorong 1 toa payoh         3
# 3                   7  2686.857477    250    Pasir Ris Street 21         6
# 4                  22  2665.537634     34           Whampoa West         3
#
#     flat_model  floor_area_sqm furnished  lease_commence_date  latitude  \
# 0  2369.965462            67.0       yes                 1983  1.344518
# 1  2369.965462            92.0       yes                 1978  1.330186
# 2  2636.211052            67.0       yes                 1971  1.332242
# 3  2878.725962           149.0       yes                 1993  1.370239
# 4  2636.211052            68.0       yes                 1972  1.320502
#
#     longitude  elevation            subzone planning_area          region  \
# 0  103.738630        0.0         yuhua east   jurong east     west region
# 1  103.938717        0.0        bedok north         bedok     east region
# 2  103.845643        0.0  toa payoh central     toa payoh  central region
# 3  103.962894        0.0    pasir ris drive     pasir ris     east region
# 4  103.863341        0.0          bendemeer       kallang  central region
#
#    monthly_rent
# 0          1600
# 1          2250
# 2          1900
# 3          2850
# 4          2100

# %%
# # Define the filename for the exported CSV file
# output_filename = "processed_data2.csv"

# # Export the DataFrame to a CSV file
# df.to_csv(output_filename, index=False)

# # Print a confirmation message
# print(f"The processed data has been exported to {output_filename}.")

# %% [markdown]
# ## Append Coe Price Coloumn ##

# %%
# Load the coe price data 
data_path = "./Datasets/auxiliary-data/sg-coe-prices.csv"
coe_df = pd.read_csv(data_path)
# Preprocess the 'year' and 'month' columns in the stock price data to match the format in the train dataset
# Combine 'year' and 'month' into a single string column
coe_df['year'] = coe_df['year'].map(str)
coe_df['year_month'] = coe_df['year'] + '-' + coe_df['month']

# Convert the 'year_month' column to a datetime format
coe_df['year_month'] = pd.to_datetime(coe_df['year_month'], format='%Y-%B')
# Calculate the number of months from the reference date for the 'year_month' column in 'coe_df'
coe_df['year_month'] = (coe_df['year_month'] - reference_date) // pd.Timedelta(days=30)

# Merge 'train_data' and 'coe_df' on 'rent_approval_date' and 'year_month'
merged_data = df.merge(coe_df, left_on='rent_approval_date', right_on='year_month', how='left')
# Create a new column 'coe_price' in the 'train_data' DataFrame and populate it with 'bidding_price' from 'coe_df'
df['coe_price'] = merged_data['price']
df.head()
# Out:
#    rent_approval_date         town  block            street_name flat_type  \
# 0                   8  2595.146199    257  Jurong East Street 24         3
# 1                  16  2438.227223    119       bedok north road         4
# 2                  21  2516.680515    157     lorong 1 toa payoh         3
# 3                   7  2686.857477    250    Pasir Ris Street 21         6
# 4                  22  2665.537634     34           Whampoa West         3
#
#     flat_model  floor_area_sqm furnished  lease_commence_date  latitude  \
# 0  2369.965462            67.0       yes                 1983  1.344518
# 1  2369.965462            92.0       yes                 1978  1.330186
# 2  2636.211052            67.0       yes                 1971  1.332242
# 3  2878.725962           149.0       yes                 1993  1.370239
# 4  2636.211052            68.0       yes                 1972  1.320502
#
#     longitude  elevation            subzone planning_area          region  \
# 0  103.738630        0.0         yuhua east   jurong east     west region
# 1  103.938717        0.0        bedok north         bedok     east region
# 2  103.845643        0.0  toa payoh central     toa payoh  central region
# 3  103.962894        0.0    pasir ris drive     pasir ris     east region
# 4  103.863341        0.0          bendemeer       kallang  central region
#
#    monthly_rent  coe_price
# 0          1600      48000
# 1          2250      47000
# 2          1900      68310
# 3          2850      62600
# 4          2100      39000

# %% [markdown]
# ## Append StockPrice Coloumn ##

# %%
# Load the stock price data 
data_path = "./Datasets/auxiliary-data/sg-stock-prices.csv"
stock_df = pd.read_csv(data_path)
# Count the number of data points for each name
name_counts = stock_df['name'].value_counts()
# Display the counts
print(name_counts)
# Out:
# name
# Triterras                                647
# Grab Holdings                            647
# Kulicke and Soffa Industries             647
# Maxeon Solar Technologies                647
# Flex                                     647
# Kenon Holdings                           647
# ASLAN Pharmaceuticals                    647
# Sea (Garena)                             647
# Grindrod Shipping                        647
# Wave Life Sciences                       647
# Pacific Century Regional Developments    646
# CapitaLand Ascott Trust                  646
# OCBC Bank                                646
# SATS                                     646
# Suntec REIT                              646
# NetLink Trust                            646
# Keppel REIT                              646
# ComfortDelGro                            646
# Singapore Land                           646
# Golden Agri-Resources                    646
# HPH Trust (Hutchison Port)               646
# Olam                                     646
# Yanlord                                  646
# Singapore Post                           646
# Riverstone Holdings                      646
# Frasers Logistics & Industrial Trust     646
# DBS Group                                646
# UOL Group                                646
# Keppel                                   646
# UOB                                      646
# Singtel                                  646
# Wilmar International                     646
# Singapore Airlines                       646
# Jardine Cycle & Carriage                 646
# City Developments                        646
# CapitaLand Mall Trust                    646
# Ascendas Reit                            646
# ST Engineering                           646
# Venture Corporation                      646
# Genting Singapore                        646
# Great Eastern                            646
# Mapletree Industrial Trust               646
# Singapore Exchange                       646
# Mapletree Logistics Trust                646
# Mapletree Commercial Trust               646
# Sembcorp                                 646
# Seatrium                                 646
# IGG Inc                                  632
# BOC Aviation                             632
# CMON                                     632
# Karooooo                                 585
# CapitaLand Investment Limited            467
# Guardforce AI                            460
# TDCX                                     458
# Society Pass                             431
# PropertyGuru                             342
# Genius Group                             325
# Ohmyhome                                  89
# CytoMed Therapeutics                      73
# Name: count, dtype: int64

# %%
# Group the DataFrame by the 'date' and calculate the average 'adjusted_close' for each date
stock_df['average_stock_price'] = stock_df.groupby('date')['adjusted_close'].transform('mean')
stock_df.head()
# Out:
#         name  symbol      date   open   high    low  close  adjusted_close  \
# 0  DBS Group  D05.SI  4/1/2021  25.13  25.34  25.01  25.34          22.833
# 1  DBS Group  D05.SI  5/1/2021  25.22  25.35  25.09  25.35          22.842
# 2  DBS Group  D05.SI  6/1/2021  25.30  25.35  25.07  25.18          22.689
# 3  DBS Group  D05.SI  7/1/2021  25.68  26.18  25.63  26.05          23.473
# 4  DBS Group  D05.SI  8/1/2021  26.55  27.47  26.50  27.42          24.707
#
#    average_stock_price
# 0             11.65890
# 1             11.80942
# 2             11.80418
# 3             12.19874
# 4             12.40866

# %%
# Convert the dates in your object-type column to pandas Timestamps
stock_df['date'] = pd.to_datetime(stock_df['date'], format="%d/%m/%Y")
stock_df['date'] = (stock_df['date'] - reference_date) // pd.Timedelta(days=30)
stock_df.head()
# Out:
#         name  symbol  date   open   high    low  close  adjusted_close  \
# 0  DBS Group  D05.SI     0  25.13  25.34  25.01  25.34          22.833
# 1  DBS Group  D05.SI     0  25.22  25.35  25.09  25.35          22.842
# 2  DBS Group  D05.SI     0  25.30  25.35  25.07  25.18          22.689
# 3  DBS Group  D05.SI     0  25.68  26.18  25.63  26.05          23.473
# 4  DBS Group  D05.SI     0  26.55  27.47  26.50  27.42          24.707
#
#    average_stock_price
# 0             11.65890
# 1             11.80942
# 2             11.80418
# 3             12.19874
# 4             12.40866

# %%
# Merge 'train_data' and 'stock_df' on 'rent_approval_date' and 'date'
merged_data2 = df.merge(stock_df, left_on='rent_approval_date', right_on='date', how='left')
# Create a new column 'stock_price' in the 'train_data' DataFrame and populate it with 'price' from 'coe_df'
df['stock_price'] = merged_data2['average_stock_price']
df.head()
# Out:
#    rent_approval_date         town  block            street_name flat_type  \
# 0                   8  2595.146199    257  Jurong East Street 24         3
# 1                  16  2438.227223    119       bedok north road         4
# 2                  21  2516.680515    157     lorong 1 toa payoh         3
# 3                   7  2686.857477    250    Pasir Ris Street 21         6
# 4                  22  2665.537634     34           Whampoa West         3
#
#     flat_model  floor_area_sqm furnished  lease_commence_date  latitude  \
# 0  2369.965462            67.0       yes                 1983  1.344518
# 1  2369.965462            92.0       yes                 1978  1.330186
# 2  2636.211052            67.0       yes                 1971  1.332242
# 3  2878.725962           149.0       yes                 1993  1.370239
# 4  2636.211052            68.0       yes                 1972  1.320502
#
#     longitude  elevation            subzone planning_area          region  \
# 0  103.738630        0.0         yuhua east   jurong east     west region
# 1  103.938717        0.0        bedok north         bedok     east region
# 2  103.845643        0.0  toa payoh central     toa payoh  central region
# 3  103.962894        0.0    pasir ris drive     pasir ris     east region
# 4  103.863341        0.0          bendemeer       kallang  central region
#
#    monthly_rent  coe_price  stock_price
# 0          1600      48000    15.610275
# 1          2250      47000    15.617471
# 2          1900      68310    15.780000
# 3          2850      62600    15.808510
# 4          2100      39000    16.099588
